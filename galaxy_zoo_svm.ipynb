jpg
#   inflating: /content/images_training_rev2/images_training_rev1/246797.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/246804.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/246821.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/246835.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/246853.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/246866.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/246873.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/246883.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/246899.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/246909.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/246918.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/246947.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/246948.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/246967.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/246971.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247037.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247064.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247117.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247122.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247147.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247173.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247190.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247198.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247201.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247230.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247234.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247242.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247256.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247269.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247287.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247307.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247309.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247310.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247318.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247326.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247334.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247343.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247344.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247347.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247362.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247373.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247390.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247420.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247440.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247473.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247475.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247491.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247522.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247542.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247553.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247569.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247570.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247582.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247589.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247610.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247623.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247653.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247659.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247660.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247692.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247715.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247759.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247783.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247789.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247801.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247807.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247813.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247817.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247822.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247865.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247875.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247897.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247912.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247926.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247966.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247977.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/247999.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/248014.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/248015.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/248017.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/248025.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/248031.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/248033.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/248044.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/248071.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/248103.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/248112.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/248160.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/248199.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/248208.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/248209.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/248225.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/248228.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/248245.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/248260.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/248289.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/248308.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/248315.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/248344.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/248367.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/248398.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/248431.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/248461.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/248466.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/248470.jpg
#   inflating: /content/images_training_rev2/images_training_rev1/248471.jpg

# %% [markdown]
# ## Load the .csv file and the images

# %%
# Load data from csv file
import os
data = pd.read_csv('/content/galaxy_zoo_labels.csv')

files = os.listdir('/content/images_training_rev2/images_training_rev1')
files.sort()


#samples
n=8000
# create a simple array with numpy empty() 
imgs = []
for i in files[:n]:
    
    img = ioi.imread('/content/images_training_rev2/images_training_rev1/'+i)
    im = img[110:310,110:310]
    img_gray = rgb2gray(im)
    imgs.append(img_gray)
    
imgs = np.array(imgs)

# Due to the large number of images, only taking 8000 images
data = data[:n]

# %% [markdown]
# ## Converting the data into the classes

# %%
class1=[]
class2=[]
class3=[]
class4=[]
class5=[]
class6=[]
class7=[]
class8=[]
class9=[]
class10=[]
class11=[]

for i in range(len(data)):
    c1 = list(data.iloc[i][['Class1.1','Class1.2','Class1.3']])
    c2 = list(data.iloc[i][['Class2.1','Class2.2']])
    c3 = list(data.iloc[i][['Class3.1','Class3.2']])
    c4 = list(data.iloc[i][['Class4.1','Class4.2']])
    c5 = list(data.iloc[i][['Class5.1','Class5.2','Class5.3','Class5.4']])
    c6 = list(data.iloc[i][['Class6.1','Class6.2']])
    c7 = list(data.iloc[i][['Class7.1','Class7.2','Class7.3']])
    c8 = list(data.iloc[i][['Class8.1', 'Class8.2', 'Class8.3', 'Class8.4', 'Class8.5', 'Class8.6', 'Class8.7']])
    c9 = list(data.iloc[i][['Class9.1', 'Class9.2', 'Class9.3']])
    c10 = list(data.iloc[i][['Class10.1', 'Class10.2', 'Class10.3']])
    c11 = list(data.iloc[i][['Class11.1', 'Class11.2', 'Class11.3', 'Class11.4', 'Class11.5', 'Class11.6']]) 
   
    class1.append((c1.index(max(c1))))
    class2.append((c2.index(max(c2))))
    class3.append((c3.index(max(c3))))
    class4.append((c4.index(max(c4))))
    class5.append((c5.index(max(c5))))
    class6.append((c6.index(max(c6))))
    class7.append((c7.index(max(c7))))
    class8.append((c8.index(max(c8))))
    class9.append((c9.index(max(c9))))
    class10.append((c10.index(max(c10))))
    class11.append((c11.index(max(c11))))

    
#print(np.sort(c1))

# %% [markdown]
# ## Split the data and images

# %%
# Dividing the data set into three sets train, test, valid with the ratio of 0.5
test_ratio = 0.4
train_set, test_set, img_train, img_test = train_test_split(class11,imgs, test_size=test_ratio, random_state=160982)
train_set, valid_set, img_train, img_valid = train_test_split(train_set,img_train, test_size=test_ratio, random_state=160982)

# %% [markdown]
# ## Reshaping the array

# %%
imtrain = img_train.reshape(img_train.shape[0],40000)
imtest = img_test.reshape(img_test.shape[0],40000)
imvalid = img_valid.reshape(img_valid.shape[0],40000)

# %% [markdown]
# ## PCA dimension reduction

# %%
pca = de.PCA(0.94)
imtrainp = pca.fit_transform(imtrain)
imtestp  = pca.transform(imtest)
imvalidp  = pca.transform(imvalid)

#print(pca.n_components_)
#print(imtrainp.shape,imtestp.shape,imvalidp.shape)

# %%
del img_train
del img_test
del img_valid

# %% [markdown]
# ## ML

# %% [markdown]
#  ## SVM with different kernels

# %%
#Create a svm Classifier


#clf = svm.SVC(decision_function_shape='ovo')

#Linear 
#clf = svm.SVC(kernel = 'linear',C=10)

#Gaussian
clf = svm.SVC(kernel='rbf', gamma=0.0001, C=10)

#Polynomial
#clf = svm.SVC(kernel='poly', degree=4, C=1000)

#Sigmoid
#clf = svm.SVC(kernel='sigmoid')


#Train the model using the training sets
clf.fit(imtrainp, train_set)

#Predict the response for test dataset
y_pred = clf.predict(imtestp)

# %%
def accuracy(test_set,y_pred):
    j=0
    acc = np.array(test_set)

    for i in range(len(y_pred)):
    
        if y_pred[i] == acc[i] :
            j+=1
    return j,len(y_pred)
        
accuracy(test_set,y_pred)
# Out:
# (2790, 3200)

# %% [markdown]
# ## Regularization

# %% [markdown]
# (1) In the kernel 'rbf', the regularization parameters are gamma, C which defines the margin. If we set C very small then it has very less accuracy. At intermediate value of it, it is showing the great accuracy and at higher it again decreases the accuracy. This is called overfitting. Thus, regularization is necessary to avoid the overfitting.

# %%
C_2d_range = [0.000001,0.01,0.1,1,10,1000]
#gamma_2d_range = [0.001,0.01,0.1,1,10]
gamma_2d_range = [0.0001]
classifiers = []
for C in C_2d_range:
    for gamma in gamma_2d_range:
        clf = SVC(kernel='rbf',C=C, gamma=gamma)
        clf.fit(imtrainp, train_set)
        y_pred = clf.predict(imtestp)
        accu = accuracy(test_set,y_pred)
        classifiers.append((C, gamma, accu[0]/len(y_pred)))
        
print(classifiers)
# Out:
# [(1e-06, 0.0001, 0.45), (0.01, 0.0001, 0.45), (0.1, 0.0001, 0.45), (1, 0.0001, 0.45), (10, 0.0001, 0.5190625), (1000, 0.0001, 0.511875)]

# %%
fig = plt.figure(figsize=(10,8))
x=[]
y=[]
z=[]
for i in range(len(classifiers)):
    x.append(classifiers[i][0])
    y.append(classifiers[i][1])
    z.append(classifiers[i][2])
  
plt.plot(x,z,color='r')
plt.xlabel('C',fontsize=14)
plt.ylabel('Accuracy',fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.savefig("/content/Results/class11.png")
plt.show()

# %% [markdown]
# ## Learning curve

# %%
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=None, train_sizes=np.linspace(.1, 1.0, 5)):
    
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    #train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    #test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    #plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                    # train_scores_mean + train_scores_std, alpha=0.1,
                    # color="r")
    #plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                    # test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt




title = "Learning Curve (SVM)"
# Cross validation with 100 iterations to get smoother mean test and train
# score curves, each time with 20% data randomly selected as a validation set.
cv = ShuffleSplit(n_splits=10, test_size=0.1, random_state=0)

estimator = SVC(gamma=0.0001,kernel='rbf',C=10)
plot_learning_curve(estimator, title, imtrainp, train_set, ylim=(0.1, 1.01), cv=cv, n_jobs=4)
plt.savefig("/content/Results/lc_class11.png")

# %% [markdown]
# ## Hyper-parameters using the validation set

# %%
# defining parameter range 
param_grid = {'C': [0.1,  10],  
              'gamma': [ 0.1, 0.0001], 
              'kernel': ['rbf','poly','sigmoid']}  
  
grid = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3);
  
# fitting the model for grid search 
grid.fit(imvalidp, valid_set);
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.451, total=   3.1s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.1s remaining:    0.0s
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.453, total=   3.1s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    6.2s remaining:    0.0s
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.451, total=   3.1s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.451, total=   3.1s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.451, total=   3.1s
# [CV] C=0.1, gamma=0.1, kernel=poly ...................................
# [CV] ....... C=0.1, gamma=0.1, kernel=poly, score=0.456, total=   2.9s
# [CV] C=0.1, gamma=0.1, kernel=poly ...................................
# [CV] ....... C=0.1, gamma=0.1, kernel=poly, score=0.419, total=   2.7s
# [CV] C=0.1, gamma=0.1, kernel=poly ...................................
# [CV] ....... C=0.1, gamma=0.1, kernel=poly, score=0.451, total=   2.9s
# [CV] C=0.1, gamma=0.1, kernel=poly ...................................
# [CV] ....... C=0.1, gamma=0.1, kernel=poly, score=0.409, total=   2.9s
# [CV] C=0.1, gamma=0.1, kernel=poly ...................................
# [CV] ....... C=0.1, gamma=0.1, kernel=poly, score=0.440, total=   3.0s
# [CV] C=0.1, gamma=0.1, kernel=sigmoid ................................
# [CV] .... C=0.1, gamma=0.1, kernel=sigmoid, score=0.341, total=   1.4s
# [CV] C=0.1, gamma=0.1, kernel=sigmoid ................................
# [CV] .... C=0.1, gamma=0.1, kernel=sigmoid, score=0.328, total=   1.4s
# [CV] C=0.1, gamma=0.1, kernel=sigmoid ................................
# [CV] .... C=0.1, gamma=0.1, kernel=sigmoid, score=0.333, total=   1.4s
# [CV] C=0.1, gamma=0.1, kernel=sigmoid ................................
# [CV] .... C=0.1, gamma=0.1, kernel=sigmoid, score=0.326, total=   1.4s
# [CV] C=0.1, gamma=0.1, kernel=sigmoid ................................
# [CV] .... C=0.1, gamma=0.1, kernel=sigmoid, score=0.383, total=   1.3s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.451, total=   1.6s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.453, total=   1.6s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.451, total=   1.6s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.451, total=   1.6s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.451, total=   1.6s
# [CV] C=0.1, gamma=0.0001, kernel=poly ................................
# [CV] .... C=0.1, gamma=0.0001, kernel=poly, score=0.451, total=   1.4s
# [CV] C=0.1, gamma=0.0001, kernel=poly ................................
# [CV] .... C=0.1, gamma=0.0001, kernel=poly, score=0.453, total=   1.4s
# [CV] C=0.1, gamma=0.0001, kernel=poly ................................
# [CV] .... C=0.1, gamma=0.0001, kernel=poly, score=0.451, total=   1.4s
# [CV] C=0.1, gamma=0.0001, kernel=poly ................................
# [CV] .... C=0.1, gamma=0.0001, kernel=poly, score=0.451, total=   1.3s
# [CV] C=0.1, gamma=0.0001, kernel=poly ................................
# [CV] .... C=0.1, gamma=0.0001, kernel=poly, score=0.451, total=   1.4s
# [CV] C=0.1, gamma=0.0001, kernel=sigmoid .............................
# [CV] . C=0.1, gamma=0.0001, kernel=sigmoid, score=0.451, total=   1.6s
# [CV] C=0.1, gamma=0.0001, kernel=sigmoid .............................
# [CV] . C=0.1, gamma=0.0001, kernel=sigmoid, score=0.453, total=   1.6s
# [CV] C=0.1, gamma=0.0001, kernel=sigmoid .............................
# [CV] . C=0.1, gamma=0.0001, kernel=sigmoid, score=0.451, total=   1.6s
# [CV] C=0.1, gamma=0.0001, kernel=sigmoid .............................
# [CV] . C=0.1, gamma=0.0001, kernel=sigmoid, score=0.451, total=   1.6s
# [CV] C=0.1, gamma=0.0001, kernel=sigmoid .............................
# [CV] . C=0.1, gamma=0.0001, kernel=sigmoid, score=0.451, total=   1.6s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.471, total=   3.1s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.471, total=   3.1s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.471, total=   3.1s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.461, total=   3.1s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.471, total=   3.1s
# [CV] C=10, gamma=0.1, kernel=poly ....................................
# [CV] ........ C=10, gamma=0.1, kernel=poly, score=0.443, total=   3.2s
# [CV] C=10, gamma=0.1, kernel=poly ....................................
# [CV] ........ C=10, gamma=0.1, kernel=poly, score=0.406, total=   3.0s
# [CV] C=10, gamma=0.1, kernel=poly ....................................
# [CV] ........ C=10, gamma=0.1, kernel=poly, score=0.424, total=   3.1s
# [CV] C=10, gamma=0.1, kernel=poly ....................................
# [CV] ........ C=10, gamma=0.1, kernel=poly, score=0.388, total=   3.2s
# [CV] C=10, gamma=0.1, kernel=poly ....................................
# [CV] ........ C=10, gamma=0.1, kernel=poly, score=0.448, total=   3.0s
# [CV] C=10, gamma=0.1, kernel=sigmoid .................................
# [CV] ..... C=10, gamma=0.1, kernel=sigmoid, score=0.354, total=   1.3s
# [CV] C=10, gamma=0.1, kernel=sigmoid .................................
# [CV] ..... C=10, gamma=0.1, kernel=sigmoid, score=0.453, total=   1.4s
# [CV] C=10, gamma=0.1, kernel=sigmoid .................................
# [CV] ..... C=10, gamma=0.1, kernel=sigmoid, score=0.326, total=   1.2s
# [CV] C=10, gamma=0.1, kernel=sigmoid .................................
# [CV] ..... C=10, gamma=0.1, kernel=sigmoid, score=0.310, total=   1.3s
# [CV] C=10, gamma=0.1, kernel=sigmoid .................................
# [CV] ..... C=10, gamma=0.1, kernel=sigmoid, score=0.357, total=   1.1s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.523, total=   1.8s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.471, total=   1.8s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.510, total=   1.8s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.518, total=   1.8s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.529, total=   1.8s
# [CV] C=10, gamma=0.0001, kernel=poly .................................
# [CV] ..... C=10, gamma=0.0001, kernel=poly, score=0.451, total=   1.4s
# [CV] C=10, gamma=0.0001, kernel=poly .................................
# [CV] ..... C=10, gamma=0.0001, kernel=poly, score=0.453, total=   1.4s
# [CV] C=10, gamma=0.0001, kernel=poly .................................
# [CV] ..... C=10, gamma=0.0001, kernel=poly, score=0.451, total=   1.4s
# [CV] C=10, gamma=0.0001, kernel=poly .................................
# [CV] ..... C=10, gamma=0.0001, kernel=poly, score=0.451, total=   1.4s
# [CV] C=10, gamma=0.0001, kernel=poly .................................
# [CV] ..... C=10, gamma=0.0001, kernel=poly, score=0.451, total=   1.4s
# [CV] C=10, gamma=0.0001, kernel=sigmoid ..............................
# [CV] .. C=10, gamma=0.0001, kernel=sigmoid, score=0.497, total=   1.8s
# [CV] C=10, gamma=0.0001, kernel=sigmoid ..............................
# [CV] .. C=10, gamma=0.0001, kernel=sigmoid, score=0.471, total=   1.8s
# [CV] C=10, gamma=0.0001, kernel=sigmoid ..............................
# [CV] .. C=10, gamma=0.0001, kernel=sigmoid, score=0.500, total=   1.8s
# [CV] C=10, gamma=0.0001, kernel=sigmoid ..............................
# [CV] .. C=10, gamma=0.0001, kernel=sigmoid, score=0.484, total=   1.8s
# [CV] C=10, gamma=0.0001, kernel=sigmoid ..............................
# [CV] .. C=10, gamma=0.0001, kernel=sigmoid, score=0.490, total=   1.8s
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:  2.0min finished

# %%
# print best parameter after tuning 
print(grid.best_params_) 
  
# print how our model looks after hyper-parameter tuning 
print(grid.best_estimator_) 

print((grid.best_score_))
# Out:
# {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# SVC(C=10, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=0.0001, kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
# 0.5104166666666667

# %% [markdown]
# ## Precision vs Recall

# %%
print(confusion_matrix(test_set,y_pred))
print(classification_report(test_set,y_pred))
# Out:
# [[1129   93    7    5    3  203]
#  [ 269  141    8    8    2  228]
#  [  19   25    1    1    0   29]
#  [  10    5    0    0    0    6]
#  [  31    4    0    0    0   21]
#  [ 439  136    3    6    1  367]]
#               precision    recall  f1-score   support
#
#            0       0.60      0.78      0.68      1440
#            1       0.35      0.21      0.27       656
#            2       0.05      0.01      0.02        75
#            3       0.00      0.00      0.00        21
#            4       0.00      0.00      0.00        56
#            5       0.43      0.39      0.41       952
#
#     accuracy                           0.51      3200
#    macro avg       0.24      0.23      0.23      3200
# weighted avg       0.47      0.51      0.48      3200

# %% [markdown]
# ## ROC Curve

# %%
from sklearn.metrics import roc_curve, auc
from sklearn import datasets
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import LinearSVC
from sklearn.preprocessing import label_binarize

import matplotlib.pyplot as plt


X=imtrainp
y=train_set

y = label_binarize(y, classes=[0,1,2,3,4,5])
n_classes = 6

# shuffle and split training and test sets
X_train, X_test, y_train, y_test =\
    train_test_split(X, y, test_size=0.6, random_state=0)

# classifier
clf = OneVsRestClassifier(clf)
y_score = clf.fit(X_train, y_train).decision_function(X_test)

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
  fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
  roc_auc[i] = auc(fpr[i], tpr[i])

# Plot of a ROC curve for a specific class
for i in range(n_classes):
    plt.figure()
    plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)' % roc_auc[i])
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')

# %%
from sklearn.metrics import precision_recall_curve, roc_curve
# precision recall curve
precision = dict()
recall = dict()
for i in range(n_classes):
    precision[i], recall[i], _ = precision_recall_curve(y_test[:, i],
                                                        y_score[:, i])
    plt.plot(recall[i], precision[i], lw=2, label='class {}'.format(i))
    
plt.xlabel("recall")
plt.ylabel("precision")
plt.legend(loc="best")
plt.title("precision vs. recall curve")
plt.savefig('/content/Results/precision_class11')
plt.show()

# %%
# roc curve
fpr = dict()
tpr = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i],
                                  y_score[:, i])
    plt.plot(fpr[i], tpr[i], lw=2, label='class {}'.format(i))

plt.xlabel("false positive rate")
plt.ylabel("true positive rate")
plt.legend(loc="best")
plt.title("ROC curve")
plt.savefig('/content/Results/roc_class11')
plt.show()

# %% [markdown]
# ## Final score

# %%
from sklearn.metrics import f1_score
print('The final score is :',f1_score(test_set, y_pred, average='weighted'))

# Model Accuracy: how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(test_set, y_pred))


# Model Precision: what percentage of positive tuples are labeled as such?
print("Precision:",metrics.precision_score(test_set, y_pred,average='weighted'))

# Model Recall: what percentage of positive tuples are labelled as such?
print("Recall:",metrics.recall_score(test_set, y_pred,average='weighted'))
# Out:
# The final score is : 0.4292537501040175
# Accuracy: 0.5190625
# Precision: 0.3766086274638301
# Recall: 0.5190625
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
